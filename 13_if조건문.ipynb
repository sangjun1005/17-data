# %%
# if 조건문 사용하기

x = 10

if x ==10:
    print("10입니다~")
# Out:
# 10입니다~

# %%
x = 10

if x ==10:
    print("10입니다~")
# Out:
# 10입니다~

# %%
# if 조건문에서 코드를 생략하기

x = 1
if x == 10:
    pass
else:
    print("I love you <3")
# Out:
# I love you <3

# %%
# if 조건문과 들여쓰기

x = 10

if x == 10:
    print('x에 들어가는 숫자는')
        print('10이랑께')
# Out:
#   Cell In[6], line 6
#     print('10이랑께')
#     ^
# IndentationError: unexpected indent

# %%
x = 10

if x == 10:
    print('x에 들어가는 숫자는')

    
print('10이랑께')
# Out:
# x에 들어가는 숫자는
# 10이랑께

# %%
# 중첩 if조건문

x = 15

if x > 10:
    print('10이상인데요')

    if x == 15:
        print('15인데요')

    if x == 20:
        print('20이여유')
# Out:
# 10이상인데요
# 15인데요

# %%
x = int(input())

if x == 10:
    print('10임 ㅋㅋ')

if x == 20:
    print('20임 ㅗ')
# Out:
# 10임 ㅋㅋ
