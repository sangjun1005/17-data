# %%
# 불과 비교연산자 사용하기

True
# Out:
# True

# %%
False
# Out:
# False

# %%
type(True)
# Out:
# bool

# %%
# 비교연산자

3 > 1
# Out:
# True

# %%
3 < 1
# Out:
# False

# %%
3 == 1
# Out:
# False

# %%
# 숫자가 같은지 다른지 비교하기

print(10 == 10)
print(10 != 5)
# Out:
# True
# True

# %%
print("Python" == "Python")
print("Python" == "python")
print("Python" != "python")
# Out:
# True
# False
# True

# %%
# 부등호 사용하기

print(10 > 20)
print(10 < 20)
print(10 >= 10)
print(10 <= 10)

print(10 >= 20)
# Out:
# False
# True
# True
# True
# False

# %%
# 객체가 같은지 다른지 비교하기

print(1 == 1.0)
print(1 is 1.0)
print(1.00 is 1.0)
print(1.00 == 1.0)
print(1 is not 1.00)
# Out:
# True
# False
# True
# True
# True
# <>:4: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
# <>:5: SyntaxWarning: "is" with 'float' literal. Did you mean "=="?
# <>:7: SyntaxWarning: "is not" with 'int' literal. Did you mean "!="?
# <>:4: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
# <>:5: SyntaxWarning: "is" with 'float' literal. Did you mean "=="?
# <>:7: SyntaxWarning: "is not" with 'int' literal. Did you mean "!="?
# C:\Users\KDS23\AppData\Local\Temp\ipykernel_19568\1011270653.py:4: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
#   print(1 is 1.0)
# C:\Users\KDS23\AppData\Local\Temp\ipykernel_19568\1011270653.py:5: SyntaxWarning: "is" with 'float' literal. Did you mean "=="?
#   print(1.00 is 1.0)
# C:\Users\KDS23\AppData\Local\Temp\ipykernel_19568\1011270653.py:7: SyntaxWarning: "is not" with 'int' literal. Did you mean "!="?
#   print(1 is not 1.00)

# %%
# 논리연산자 사용하기
print(True and True)
print(True and False)
print(False and False)
print(True or True)
print(True or False)
print(False or False)
print(not True)
print(not False)
# Out:
# True
# False
# False
# True
# True
# False
# False
# True

# %%
not True and False or not False
# Out:
# True

# %%
# 논리연산자와 비교연산자를 함께 사용하기

print(10 == 10 and 10 != 5)
# Out:
# True

# %%
print(10>5 or 10 < 3)
print(not 10 > 5)
print(not 1 is 1.0)
# Out:
# True
# False
# True
# <>:3: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
# <>:3: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
# C:\Users\KDS23\AppData\Local\Temp\ipykernel_19568\2260198109.py:3: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
#   print(not 1 is 1.0)

# %%
a= 92
b= 47
c= 86
d= 81

print(a >= 50 and b >= 50 and c >= 50 and d >= 50)
# Out:
# False

# %%
a, b, c, d = map(int, input().split())
print(a >= 90 and b>80 and c>85 and d>=80)
# Out:
# True

# %%
a, b, c, d = map(int, input().split())
print(a >= 90 and b>80 and c>85 and d>=80)
# Out:
# False
