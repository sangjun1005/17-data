# %%
# 딕셔너리 만들기

# 딕셔너리 = {
#     키1:값1
#     키2:값2
#     ...
# }

lux = {
    "health":490,
    "mana":334,
    "melee":550,
    "armor":18.71
}
print(lux)
# Out:
# {'health': 490, 'mana': 334, 'melee': 550, 'armor': 18.71}

# %%
# 키 이름이 중복이 되면?

lux = {
    "health":490,
    "health":800,
    "mana":334,
    "melee":550,
    "armor":18.71
}
print(lux)
# Out:
# {'health': 800, 'mana': 334, 'melee': 550, 'armor': 18.71}

# %%
# 딕셔너리 키의 자료형

x = {
    100:"hundred",
    False:0,
    3.5:[3.5,3.5]
}
print(x)
# Out:
# {100: 'hundred', False: 0, 3.5: [3.5, 3.5]}

# %%
x = {
    [10,20]:100
}
print(x)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 x = {
#       2     [10,20]:100
#       3 }
#       4 print(x)
#
# TypeError: cannot use 'list' as a dict key (unhashable type: 'list')

# %%
# 빈 딕셔너리 만들기

x = {}
y = dict()

print(x)
print(y)
print(type(x))
print(type(y))
# Out:
# {}
# {}
# <class 'dict'>
# <class 'dict'>

# %%
# dict로 딕셔너리 만들기

dict(
    health=490,
    mana=344,
    melee=550,
    armor=18.72
)
# Out:
# {'health': 490, 'mana': 344, 'melee': 550, 'armor': 18.72}

# %%
lux=dict(zip(
    ['health','mana','melee','armor'],
    [490, 334, 550, 18.72]
))
print(lux)
# Out:
# {'health': 490, 'mana': 334, 'melee': 550, 'armor': 18.72}

# %%
a = dict([
    ('health',490),
    ('mana',334),
    ('melee',550),
    ('armor',18.72)
])
print(a)
# Out:
# {'health': 490, 'mana': 334, 'melee': 550, 'armor': 18.72}

# %%
lux = dict({'health': 490, 'mana': 334, 'melee': 550, 'armor': 18.72})
print(lux)
# Out:
# {'health': 490, 'mana': 334, 'melee': 550, 'armor': 18.72}

# %%
a = 'python'
b = 'python'
c = a[1::2]
d = b[::2]
print(c+d)
# Out:
# yhnpto

# %%
camile = {
    'health':575.6,
    'health_regan':1.7,
    'mana':338.8,
    'mana_regan':1.63,
    'melee':125,
    'attack_damage':60,
    'attack_speed0':0.625,
    'armor':26,
    'magic_resistance':32.1,
    'movement_speed':340
}

print(camile['health'])
print(camile['movement_speed'])
# Out:
# 575.6
# 340

# %%
dict(zip(
    ['health','health_regan','mana','mana_regan'],
    [575.6,1.7,338.8,1.63]
))
# Out:
# {'health': 575.6, 'health_regan': 1.7, 'mana': 338.8, 'mana_regan': 1.63}

# %%
# 딕셔너리의 키에 접근하고 값 할당하기

lux = {'health': 490, 'mana': 334, 'melee': 550, 'armor': 18.72}

lux['health']
lux['armor']
# Out:
# 18.72

# %%
lux['health'] = 2037
lux['mana'] = 1104
print(lux)
# Out:
# {'health': 2037, 'mana': 1104, 'melee': 550, 'armor': 18.72}

# %%
lux['mana_regen'] = 3.28
print(lux)
# Out:
# {'health': 2037, 'mana': 1104, 'melee': 550, 'armor': 18.72, 'mana_regen': 3.28}

# %%
lux['attack_speed']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 lux['attack_speed']
#
# KeyError: 'attack_speed'

# %%
lux.get('attack_speed', 3.14)
print(lux)
# Out:
# {'health': 2037, 'mana': 1104, 'melee': 550, 'armor': 18.72, 'mana_regen': 3.28}

# %%
# 딕셔너리에 키가 있는 지 확인하기

print(lux)
# Out:
# {'health': 2037, 'mana': 1104, 'melee': 550, 'armor': 18.72, 'mana_regen': 3.28}

# %%
'health' in lux
# Out:
# True

# %%
2037 in lux
# Out:
# False

# %%
# 딕셔너리 키 개수 구하기

lux
# Out:
# {'health': 2037,
#  'mana': 1104,
#  'melee': 550,
#  'armor': 18.72,
#  'mana_regen': 3.28}

# %%
len(lux)
# Out:
# 5

# %%
a = 1548,87,9,465
a[0:2]
# Out:
# (1548, 87)
