# %%
# import 모듈 가져오기

# import 모듈
# import 모듈1, 모듈2

# 모듈.변수
# 모듈.함수()
# 모듈.클래스()

import math

math.pi
math.sqrt(4.0)
# Out:
# 2.0

# %%
# import as로 모듈 이름 지정하기

# import 모듈 as 이름

import math as m

# %%
# from import로 묘듈의 일부만 가져오기

from math import pi
pi
# Out:
# 3.141592653589793

# %%
# from import로 모듈의 일부를 가져온 뒤 이름 지정하기

from math import sqrt as s, pi as p

s(4.0)
# Out:
# 2.0

# %%
# import로 패키지 가져오기

import urllib.request
response = urllib.request.urlopen('http://www.google.co.kr')
response.status
# Out:
# 200
