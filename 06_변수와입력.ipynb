# %%
# 변수 만들기

## 1. 영문문자, 숫자를 사용할 수 있다.
## 2. 대소문자를 구분할 수 있다.
## 3. 문자부터 시작을 해야하고, 숫자부터 시작은 안 된다. 
## 4. _(언더바)로 시작할 수 있다.
## 5. 특수문자(+,-,*,/,%, ..)는 사용할 수 없다.
## 6. 파이썬 키워드(if, for, while, def, class, ...)는 사용할 수 없다. 

stand_alone = 1
StandAlone = 1
standAlone = 1
# stand-alone = 1 (X)
# stand alone = 1 (X)

# %%
# 변수 열개를 한번에 만들기

x,y,z = 10,20,30
print(x)  # 10
print(y)  # 20
print(z)  # 30
# Out:
# 10
# 20
# 30

# %%
# x, y, z = 10, 20

# %%
x = y = z = 10
print(x)  # 10
print(y)  # 10 
print(z)  # 10
# Out:
# 10
# 10
# 10

# %%
x, y = 10, 20
x, y = y, x
print(x)  # 20
print(y)  # 10
# Out:
# 20
# 10

# %%
# 변수로 계산하기

a = 10
b = 20
a+b
# Out:
# 30

# %%
# 산술 연산 후 할당 연산자 사용하기

a = 10
a + 20
print(a)  # 10
# Out:
# 10

# %%
b = 10
b += 20 #b = b + 20
print(b)  # 30
# Out:
# 30

# %%
# 입력값을 변수에 저장하기

input("")
# Out:
# 'hello world'

# %%
x = input("")

# %%
print(x)
# Out:
# hello world

# %%
# 입력값을 정수로 반환하기

a = int(input("첫 번째 숫자를 입력하세요: "))
b = int(input("두 번째 숫자를 입력하세요: "))

print(a + b)
# Out:
# 30

# %%
# 입력값을 변수 두 개에 저장하기

a, b = input("문자열 두 개를 입력하세요: ").split()

# %%
print(a)
print(b)
# Out:
# hello
# world

# %%
"hello world".split()  # ['hello', 'world']
# Out:
# ['hello', 'world']

# %%
a, b = ['hello', 'world']

# %%
print(a)
print(b)
# Out:
# hello
# world

# %%
a, b = input("숫자 두 개를 입력하세요.").split()
a = int(a)
b = int(b)

a + b
# Out:
# 30

# %%
list(map(int, ["10", "20"]))
# Out:
# [10, 20]

# %%
a, b = map(int, input("숫자 두 개를 입력하세요.").split())
print(a)
print(b)
print(a + b)
# Out:
# 10
# 20
# 30

# %%
# 입력받은 값을 콤마를 기준으로 분리하기

a, b = map(int, input("숫자 두 개를 입력하세요.").split(','))
print(a+b)
# Out:
# 30

# %%
print("10,20".split())
print("10,20".split(','))
# Out:
# ['10,20']
# ['10', '20']

# %%
a, b = map(int, input("숫자를 두 개를 입력하세요.").split())
print(a)
print(b)
print(a + b)
# Out:
# 10
# 30
# 40

# %%
a= 20
b= 30
c -= b #c-= b 는 c = c - b 와 같다.
print(c)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 3
#       1 a= 20
#       2 b= 30
# ----> 3 c -= b
#       4 print(c)
#
# NameError: name 'c' is not defined

# %%
del a

b= 20
b+=1
print(b)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 del a
#       2
#       3 b= 20
#       4 b+=1
#
# NameError: name 'a' is not defined

# %%
a,b,c = map(int,input("숫자 세 개를 입력하세요.").split())
print(a+b+c)
# Out:
# 40

# %%
a=50
b=100
c=None

print(a)
print(b)
print(c)
# Out:
# 50
# 100
# None
