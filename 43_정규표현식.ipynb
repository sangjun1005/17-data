# %%
# 문자열 판단하기

import re

re.match('hello','hello, world')
# Out:
# <re.Match object; span=(0, 5), match='hello'>

# %%
re.search('hello', 'hello, world')
re.search('world!$', 'hello, world!')
# Out:
# <re.Match object; span=(7, 13), match='world!'>

# %%
# 지정한 문자열이 하나라도 포함되는지 판단하기

re.match('hello|world','hello')
# Out:
# <re.Match object; span=(0, 5), match='hello'>

# %%
# 범위 판단하기

print(re.match('[0-9]*','1234'))
print(re.match('[0-9]+','1234'))
print(re.match('[0-9]+','abcd'))
# Out:
# <re.Match object; span=(0, 4), match='1234'>
# <re.Match object; span=(0, 4), match='1234'>
# None

# %%
print(re.match('a*b','b'))
print(re.match('a+b','b'))
print(re.match('a*b','aab'))
# Out:
# <re.Match object; span=(0, 1), match='b'>
# None
# <re.Match object; span=(0, 3), match='aab'>

# %%
# 문자가 한개만 있는지 판단하기

# 문자? 
# [0-9]?

print(re.match('abc?d','abd'))
print(re.match('ab[0-9]?c','ab3c'))
print(re.match('ab.d','abxd'))
# Out:
# <re.Match object; span=(0, 3), match='abd'>
# <re.Match object; span=(0, 4), match='ab3c'>
# <re.Match object; span=(0, 4), match='abxd'>

# %%
## 문자 개수 판단하기

# 문자{개수}
# (문자열){개수}

print(re.match('h{3}','hhhello'))
print(re.match('(hello){3}','hellohellohelloworld'))
# Out:
# <re.Match object; span=(0, 3), match='hhh'>
# <re.Match object; span=(0, 15), match='hellohellohello'>

# %%
# [0-9]{개수}

print(re.match('[0-9]{3}-[0-9]{3,4}-[0-9]{4}','010-3803-1620'))
print(re.match('[0-9]{3}-[0-9]{3,4}-[0-9]{4}','010-3803-162'))
# Out:
# <re.Match object; span=(0, 13), match='010-3803-1620'>
# None

# %%
## 숫자와 영문문자, 한글을 조합해서 판단하기

# a-z
# A-Z

print(re.match('[a-zA-Z0-9]+','hello1234'))
print(re.match('[A-Z0-9]+','hello1234'))
print(re.match('[가-힣]+','권상준'))
# Out:
# <re.Match object; span=(0, 9), match='hello1234'>
# None
# <re.Match object; span=(0, 3), match='권상준'>

# %%
## 특정 문자 범위에 포함되지 않는지 판단하기

# [^범위]*
# [^범위]+

print(re.match('[^A-Z]+','Hello'))
print(re.match('[^A-Z]+','hello'))
# Out:
# None
# <re.Match object; span=(0, 5), match='hello'>

# %%
# ^[범위]*
# ^[범위]+

print(re.search('^[A-Z]+','Hello'))
# Out:
# <re.Match object; span=(0, 1), match='H'>

# %%
# \d = [0-9]
# \D = [^0-9]
# \w = [a-zA-Z0-9_]
# \W = [^a-zA-z0-9_]

# %%
## 패턴에 매칭되는 모든 문자열 가져오기

re.findall('[0-9]','1 2 fizz 4 fuzz 7 8')
# Out:
# ['1', '2', '4', '7', '8']

# %%
# 문자열 바꾸기
